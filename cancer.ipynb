# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
d = pd.read_csv('C:/Users/Ragul/Downloads/Machine Learning-1/Self/cancer_reg.csv')
d
# Out:
#       avganncount  avgdeathsperyear  target_deathrate  incidencerate  \
# 0     1397.000000               469             164.9     489.800000
# 1      173.000000                70             161.3     411.600000
# 2      102.000000                50             174.7     349.700000
# 3      427.000000               202             194.8     430.400000
# 4       57.000000                26             144.4     350.100000
# ...           ...               ...               ...            ...
# 3042  1962.667684                15             149.6     453.549422
# 3043  1962.667684                43             150.1     453.549422
# 3044  1962.667684                46             153.9     453.549422
# 3045  1962.667684                52             175.0     453.549422
# 3046  1962.667684                48             213.6     453.549422
#
#       medincome  popest2015  povertypercent  studypercap           binnedinc  \
# ...

# %%
d.skew()
# Out:
# avganncount                 0.381543
# avgdeathsperyear           11.949188
# target_deathrate            0.274724
# incidencerate               0.771935
# medincome                   1.408071
# popest2015                 14.289926
# povertypercent              0.930713
# studypercap                 8.713690
# medianage                   9.989944
# medianagemale               0.132041
# medianagefemale            -0.208384
# avghouseholdsize           -3.380988
# percentmarried             -0.653487
# pctnohs18_24                0.973345
# pcths18_24                  0.179209
# pctsomecol18_24             0.392411
# pctbachdeg18_24             1.956201
# pcths25_over               -0.333635
# pctbachdeg25_over           1.094837
# pctemployed16_over         -0.387649
# pctunemployed16_over        0.891061
# pctprivatecoverage         -0.393537
# pctprivatecoveragealone    -0.009915
# pctempprivcoverage          0.089416
# pctpubliccoverage          -0.005436
# ...

# %%
np.log(d).skew()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-294-833be3bfb3e4> in <module>
# ----> 1 np.log(d).skew()
#
# AttributeError: 'float' object has no attribute 'log'

# %%
sns.distplot(d.avganncount)

# %%
d.avganncount = np.power(d.avganncount,0.16)

# %%
d.shape
# Out:
# (3047, 34)

# %%
d.dtypes
# Out:
# avganncount                float64
# avgdeathsperyear             int64
# target_deathrate           float64
# incidencerate              float64
# medincome                    int64
# popest2015                   int64
# povertypercent             float64
# studypercap                float64
# binnedinc                   object
# medianage                  float64
# medianagemale              float64
# medianagefemale            float64
# geography                   object
# avghouseholdsize           float64
# percentmarried             float64
# pctnohs18_24               float64
# pcths18_24                 float64
# pctsomecol18_24            float64
# pctbachdeg18_24            float64
# pcths25_over               float64
# pctbachdeg25_over          float64
# pctemployed16_over         float64
# pctunemployed16_over       float64
# pctprivatecoverage         float64
# pctprivatecoveragealone    float64
# pctempprivcoverage         float64
# pctpubliccoverage          float64
# ...

# %%
d["binnedinc"]=d["binnedinc"].map({'[22640, 34218.1]':0,'(34218.1, 37413.8]':1,'(37413.8, 40362.7]':2,'(40362.7, 42724.4]':3,'(42724.4, 45201]':4,'(45201, 48021.6]':5,'(48021.6, 51046.4]':6,'(51046.4, 54545.6]':7,'(54545.6, 61494.5]':8,'(61494.5, 125635]':9})

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3047 entries, 0 to 3046
# Data columns (total 34 columns):
# avganncount                3047 non-null float64
# avgdeathsperyear           3047 non-null int64
# target_deathrate           3047 non-null float64
# incidencerate              3047 non-null float64
# medincome                  3047 non-null int64
# popest2015                 3047 non-null int64
# povertypercent             3047 non-null float64
# studypercap                3047 non-null float64
# binnedinc                  3047 non-null int64
# medianage                  3047 non-null float64
# medianagemale              3047 non-null float64
# medianagefemale            3047 non-null float64
# geography                  3047 non-null object
# avghouseholdsize           3047 non-null float64
# percentmarried             3047 non-null float64
# pctnohs18_24               3047 non-null float64
# pcths18_24                 3047 non-null float64
# ...

# %%
d.isnull().sum()
# Out:
# avganncount                   0
# avgdeathsperyear              0
# target_deathrate              0
# incidencerate                 0
# medincome                     0
# popest2015                    0
# povertypercent                0
# studypercap                   0
# binnedinc                     0
# medianage                     0
# medianagemale                 0
# medianagefemale               0
# geography                     0
# avghouseholdsize              0
# percentmarried                0
# pctnohs18_24                  0
# pcths18_24                    0
# pctsomecol18_24            2285
# pctbachdeg18_24               0
# pcths25_over                  0
# pctbachdeg25_over             0
# pctemployed16_over          152
# pctunemployed16_over          0
# pctprivatecoverage            0
# pctprivatecoveragealone     609
# pctempprivcoverage            0
# pctpubliccoverage             0
# pctpubliccoveragealone        0
# pctwhite                      0
# ...

# %%
d.isnull().sum()/len(d)*100
# Out:
# avganncount                 0.000000
# avgdeathsperyear            0.000000
# target_deathrate            0.000000
# incidencerate               0.000000
# medincome                   0.000000
# popest2015                  0.000000
# povertypercent              0.000000
# studypercap                 0.000000
# binnedinc                   0.000000
# medianage                   0.000000
# medianagemale               0.000000
# medianagefemale             0.000000
# geography                   0.000000
# avghouseholdsize            0.000000
# percentmarried              0.000000
# pctnohs18_24                0.000000
# pcths18_24                  0.000000
# pctsomecol18_24            74.991795
# pctbachdeg18_24             0.000000
# pcths25_over                0.000000
# pctbachdeg25_over           0.000000
# pctemployed16_over          4.988513
# pctunemployed16_over        0.000000
# pctprivatecoverage          0.000000
# pctprivatecoveragealone    19.986872
# ...

# %%
d.geography = d.geography.map(lambda x:x.split(',')[1].lstrip())
d.geography
# Out:
# 0       Washington
# 1       Washington
# 2       Washington
# 3       Washington
# 4       Washington
#            ...
# 3042        Kansas
# 3043        Kansas
# 3044        Kansas
# 3045        Kansas
# 3046        Kansas
# Name: geography, Length: 3047, dtype: object

# %%
pd.options.display.max_columns = None

# %%
d
# Out:
#       avganncount  avgdeathsperyear  target_deathrate  incidencerate  \
# 0     1397.000000               469             164.9     489.800000
# 1      173.000000                70             161.3     411.600000
# 2      102.000000                50             174.7     349.700000
# 3      427.000000               202             194.8     430.400000
# 4       57.000000                26             144.4     350.100000
# ...           ...               ...               ...            ...
# 3042  1962.667684                15             149.6     453.549422
# 3043  1962.667684                43             150.1     453.549422
# 3044  1962.667684                46             153.9     453.549422
# 3045  1962.667684                52             175.0     453.549422
# 3046  1962.667684                48             213.6     453.549422
#
#       medincome  popest2015  povertypercent  studypercap  binnedinc  \
# 0         61898      260131            11.2   499.748204          9
# ...

# %%
d.geography = d.geography.replace(['Connecticut','Maine','Massachusetts','New Hampshire','Rhode Island','Vermont','New Jersey','New York','Pennsylvania'],
                                                      'North-East')

# %%
d.geography.value_counts()
# Out:
# Texas                   233
# North-East              217
# Georgia                 155
# Virginia                125
# Kentucky                120
# Missouri                115
# Illinois                102
# Kansas                  102
# Iowa                     99
# North Carolina           99
# Tennessee                95
# Indiana                  92
# Minnesota                87
# Ohio                     87
# Michigan                 83
# Mississippi              82
# Nebraska                 80
# Oklahoma                 77
# Arkansas                 75
# Wisconsin                72
# Florida                  66
# Louisiana                64
# Alabama                  63
# Colorado                 60
# South Dakota             59
# California               57
# West Virginia            55
# North Dakota             51
# Montana                  48
# South Carolina           46
# Idaho                    42
# Washington               39
# Oregon                   36
# ...

# %%
d.geography = d.geography.replace([('Illinois','Indiana','Michigan','Ohio','Wisconsin','Iowa','Kansas','Minnesota','Missouri','Nebraska','North Dakota','South Dakota')],
                                                      'Mid-West')

# %%
d.geography = d.geography.replace([('Delaware','Florida','Georgia','Maryland','North Carolina','South Carolina','Virginia','District of Columbia','West Virginia','Alabama','Kentucky','Mississippi','Tennessee','Arkansas','Louisiana','Oklahoma','Texas')],
                                                      'South')

# %%
d.geography = d.geography.replace([('Arizona','Colorado','Idaho','Montana','Nevada','New Mexico','Utah','Wyoming','Alaska','California','Hawaii','Oregon','Washington')],
                                                      'West')

# %%
d = d.drop('pctsomecol18_24',1)

# %%
d.head(2)
# Out:
#    avganncount  avgdeathsperyear  target_deathrate  incidencerate  medincome  \
# 0       1397.0               469             164.9          489.8      61898
# 1        173.0                70             161.3          411.6      48127
#
#    popest2015  povertypercent  studypercap  binnedinc  medianage  \
# 0      260131            11.2   499.748204          9       39.3
# 1       43269            18.6    23.111234          6       33.0
#
#    medianagemale  medianagefemale geography  avghouseholdsize  percentmarried  \
# 0           36.9             41.7      West              2.54            52.5
# 1           32.2             33.7      West              2.34            44.5
#
#    pctnohs18_24  pcths18_24  pctbachdeg18_24  pcths25_over  pctbachdeg25_over  \
# 0          11.5        39.5              6.9          23.2               19.6
# 1           6.1        22.4              7.5          26.0               22.7
#
# ...

# %%
d.pctemployed16_over.describe()
# Out:
# count    2895.000000
# mean       54.152642
# std         8.315064
# min        17.600000
# 25%        48.600000
# 50%        54.500000
# 75%        60.300000
# max        80.100000
# Name: pctemployed16_over, dtype: float64

# %%
fil = d.pctemployed16_over.fillna(d.pctemployed16_over.median())

# %%
d.pctemployed16_over = fil

# %%
d.isnull().sum()
# Out:
# avganncount                  0
# avgdeathsperyear             0
# target_deathrate             0
# incidencerate                0
# medincome                    0
# popest2015                   0
# povertypercent               0
# studypercap                  0
# binnedinc                    0
# medianage                    0
# medianagemale                0
# medianagefemale              0
# geography                    0
# avghouseholdsize             0
# percentmarried               0
# pctnohs18_24                 0
# pcths18_24                   0
# pctbachdeg18_24              0
# pcths25_over                 0
# pctbachdeg25_over            0
# pctemployed16_over           0
# pctunemployed16_over         0
# pctprivatecoverage           0
# pctprivatecoveragealone    609
# pctempprivcoverage           0
# pctpubliccoverage            0
# pctpubliccoveragealone       0
# pctwhite                     0
# pctblack                     0
# pctasian                     0
# ...

# %%
fil_1 = d.pctprivatecoveragealone.fillna(d.pctprivatecoveragealone.median())
fil_2 = d.pctprivatecoveragealone.fillna(d.pctprivatecoveragealone.mean())

# %%
d.pctprivatecoveragealone.describe()
# Out:
# count    2438.000000
# mean       48.453774
# std        10.083006
# min        15.700000
# 25%        41.000000
# 50%        48.700000
# 75%        55.600000
# max        78.900000
# Name: pctprivatecoveragealone, dtype: float64

# %%
fil_1.describe()
# Out:
# count    3047.000000
# mean       48.502987
# std         9.019423
# min        15.700000
# 25%        43.100000
# 50%        48.700000
# 75%        53.800000
# max        78.900000
# Name: pctprivatecoveragealone, dtype: float64

# %%
fil_2.describe()
# Out:
# count    3047.000000
# mean       48.453774
# std         9.018885
# min        15.700000
# 25%        43.100000
# 50%        48.453774
# 75%        53.800000
# max        78.900000
# Name: pctprivatecoveragealone, dtype: float64

# %%
d.pctprivatecoveragealone = fil_2

# %%
d.isnull().sum()
# Out:
# avganncount                0
# avgdeathsperyear           0
# target_deathrate           0
# incidencerate              0
# medincome                  0
# popest2015                 0
# povertypercent             0
# studypercap                0
# binnedinc                  0
# medianage                  0
# medianagemale              0
# medianagefemale            0
# geography                  0
# avghouseholdsize           0
# percentmarried             0
# pctnohs18_24               0
# pcths18_24                 0
# pctbachdeg18_24            0
# pcths25_over               0
# pctbachdeg25_over          0
# pctemployed16_over         0
# pctunemployed16_over       0
# pctprivatecoverage         0
# pctprivatecoveragealone    0
# pctempprivcoverage         0
# pctpubliccoverage          0
# pctpubliccoveragealone     0
# pctwhite                   0
# pctblack                   0
# pctasian                   0
# pctotherrace               0
# pctmarriedhouseholds       0
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3047 entries, 0 to 3046
# Data columns (total 33 columns):
# avganncount                3047 non-null float64
# avgdeathsperyear           3047 non-null int64
# target_deathrate           3047 non-null float64
# incidencerate              3047 non-null float64
# medincome                  3047 non-null int64
# popest2015                 3047 non-null int64
# povertypercent             3047 non-null float64
# studypercap                3047 non-null float64
# binnedinc                  3047 non-null int64
# medianage                  3047 non-null float64
# medianagemale              3047 non-null float64
# medianagefemale            3047 non-null float64
# geography                  3047 non-null object
# avghouseholdsize           3047 non-null float64
# percentmarried             3047 non-null float64
# pctnohs18_24               3047 non-null float64
# pcths18_24                 3047 non-null float64
# ...

# %%
d
# Out:
#       avganncount  avgdeathsperyear  target_deathrate  incidencerate  \
# 0     1397.000000               469             164.9     489.800000
# 1      173.000000                70             161.3     411.600000
# 2      102.000000                50             174.7     349.700000
# 3      427.000000               202             194.8     430.400000
# 4       57.000000                26             144.4     350.100000
# ...           ...               ...               ...            ...
# 3042  1962.667684                15             149.6     453.549422
# 3043  1962.667684                43             150.1     453.549422
# 3044  1962.667684                46             153.9     453.549422
# 3045  1962.667684                52             175.0     453.549422
# 3046  1962.667684                48             213.6     453.549422
#
#       medincome  popest2015  povertypercent  studypercap  binnedinc  \
# 0         61898      260131            11.2   499.748204          9
# ...

# %%
num_data = d.select_dtypes(include=np.number)
num_data
# Out:
#       avganncount  avgdeathsperyear  target_deathrate  incidencerate  \
# 0     1397.000000               469             164.9     489.800000
# 1      173.000000                70             161.3     411.600000
# 2      102.000000                50             174.7     349.700000
# 3      427.000000               202             194.8     430.400000
# 4       57.000000                26             144.4     350.100000
# ...           ...               ...               ...            ...
# 3042  1962.667684                15             149.6     453.549422
# 3043  1962.667684                43             150.1     453.549422
# 3044  1962.667684                46             153.9     453.549422
# 3045  1962.667684                52             175.0     453.549422
# 3046  1962.667684                48             213.6     453.549422
#
#       medincome  popest2015  povertypercent  studypercap  binnedinc  \
# 0         61898      260131            11.2   499.748204          9
# ...

# %%
corr = d.corr()

# %%
plt.figure(figsize=(30, 30))
sns.heatmap(corr, cmap='YlGnBu', vmax=1.0, vmin=-1.0, annot = True, annot_kws={"size": 15}, )
plt.title('Correlation between numeric features')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3047 entries, 0 to 3046
# Data columns (total 33 columns):
# avganncount                3047 non-null float64
# avgdeathsperyear           3047 non-null int64
# target_deathrate           3047 non-null float64
# incidencerate              3047 non-null float64
# medincome                  3047 non-null int64
# popest2015                 3047 non-null int64
# povertypercent             3047 non-null float64
# studypercap                3047 non-null float64
# binnedinc                  3047 non-null int64
# medianage                  3047 non-null float64
# medianagemale              3047 non-null float64
# medianagefemale            3047 non-null float64
# geography                  3047 non-null object
# avghouseholdsize           3047 non-null float64
# percentmarried             3047 non-null float64
# pctnohs18_24               3047 non-null float64
# pcths18_24                 3047 non-null float64
# ...

# %%
num_data.shape
# Out:
# (3047, 32)

# %%
 for i in d.columns:
    sns.boxplot(d[i])
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-185-b213e03799d8> in <module>
#       1 for i in d.columns:
# ----> 2    sns.boxplot(d[i])
#       3    plt.show()
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, notch, ax, **kwargs)
#    2235     kwargs.update(dict(whis=whis, notch=notch))
#    2236
# -> 2237     plotter.plot(ax, kwargs)
#    2238     return ax
#    2239
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in plot(self, ax, boxplot_kws)
#     547     def plot(self, ax, boxplot_kws):
#     548         """Make the plot."""
# --> 549         self.draw_boxplot(ax, boxplot_kws)
#     550         self.annotate_axes(ax)
#     551         if self.orient == "h":
#
# ...

# %%
q1=d.quantile(0.25)
q3=d.quantile(0.75)
iqr=q3-q1
lb=q1-(iqr*1.5)
ub=q3+(iqr*1.5)
#d=d.replace(d[d<lb],d.quantile(0.05))
#d=d.replace(d[d>ub],d.quantile(0.95))

# %%
ind = d[(d>ub) | (d<lb)].index
ind
# Out:
# RangeIndex(start=0, stop=3047, step=1)

# %%
data = d.drop(ind)

# %%
data
# Out:
# Empty DataFrame
# Columns: [avganncount, avgdeathsperyear, target_deathrate, incidencerate, medincome, popest2015, povertypercent, studypercap, binnedinc, medianage, medianagemale, medianagefemale, geography, avghouseholdsize, percentmarried, pctnohs18_24, pcths18_24, pctbachdeg18_24, pcths25_over, pctbachdeg25_over, pctemployed16_over, pctunemployed16_over, pctprivatecoverage, pctprivatecoveragealone, pctempprivcoverage, pctpubliccoverage, pctpubliccoveragealone, pctwhite, pctblack, pctasian, pctotherrace, pctmarriedhouseholds, birthrate]
# Index: []

# %%
 for i in d.columns:
    sns.boxplot(d[i])
    plt.show()

# %%
d.shape
# Out:
# (3047, 32)

# %%
x = pd.get_dummies(d.geography,drop_first=True)

# %%
d = d.drop('geography',1)

# %%
d = pd.concat([d,x],axis=1)

# %%
d.isnull().sum()
# Out:
# avganncount                0
# avgdeathsperyear           0
# target_deathrate           0
# incidencerate              0
# medincome                  0
# popest2015                 0
# povertypercent             0
# studypercap                0
# binnedinc                  0
# medianage                  0
# medianagemale              0
# medianagefemale            0
# avghouseholdsize           0
# percentmarried             0
# pctnohs18_24               0
# pcths18_24                 0
# pctbachdeg18_24            0
# pcths25_over               0
# pctbachdeg25_over          0
# pctemployed16_over         0
# pctunemployed16_over       0
# pctprivatecoverage         0
# pctprivatecoveragealone    0
# pctempprivcoverage         0
# pctpubliccoverage          0
# pctpubliccoveragealone     0
# pctwhite                   0
# pctblack                   0
# pctasian                   0
# pctotherrace               0
# pctmarriedhouseholds       0
# birthrate                  0
# ...

# %%
import statsmodels.api as sm

# %%
out = d.target_deathrate
inp = d.drop('target_deathrate',1)

# %%
inp_c = sm.add_constant(inp)
# Out:
# C:\Users\Ragul\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
mod = sm.OLS(out,inp_c)
ols_mod = mod.fit()
ols_mod.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:       target_deathrate   R-squared:                       0.542
# Model:                            OLS   Adj. R-squared:                  0.537
# Method:                 Least Squares   F-statistic:                     105.0
# Date:                Sat, 12 Sep 2020   Prob (F-statistic):               0.00
# Time:                        10:55:59   Log-Likelihood:                -13017.
# No. Observations:                3047   AIC:                         2.610e+04
# Df Residuals:                    3012   BIC:                         2.631e+04
# Df Model:                          34
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['VIF']=[variance_inflation_factor(inp.values,i) for i in range(inp.shape[1])]
vif['feature']=inp.columns
vif.sort_values('VIF',ascending=False)
# Out:
#             VIF                  feature
# 8   1436.454256                medianage
# 10  1066.407609          medianagefemale
# 9   1031.556439            medianagemale
# 29   739.170554     pctmarriedhouseholds
# 12   699.492879           percentmarried
# 20   563.933278       pctprivatecoverage
# 3    441.529104                medincome
# 23   433.528777        pctpubliccoverage
# 11   370.765633         avghouseholdsize
# 18   227.376333       pctemployed16_over
# 24   205.345145   pctpubliccoveragealone
# 25   185.174532                 pctwhite
# 21   147.263875  pctprivatecoveragealone
# 22   147.121255       pctempprivcoverage
# 2    123.279745            incidencerate
# 16   101.845534             pcths25_over
# 5     66.569947           povertypercent
# 7     59.751334                binnedinc
# 17    45.372497        pctbachdeg25_over
# 14    28.858000               pcths18_24
# 19    20.044110     pctunemployed16_over
# 30    15.162727                birthrate
# ...

# %%
inp_1=inp.drop(['medianage'],1)      #check individual then add one by one into drop 
vif=pd.DataFrame()
vif['VIF']=[variance_inflation_factor(inp_1.values,i) for i in range(inp_1.shape[1])]
vif['feature']=inp_1.columns
vif.sort_values('VIF',ascending=False)
# Out:
#            VIF                  feature
# 28  736.536376     pctmarriedhouseholds
# 9   735.685373          medianagefemale
# 11  695.836469           percentmarried
# 8   643.487666            medianagemale
# 19  563.933097       pctprivatecoverage
# 3   441.478528                medincome
# 22  433.402398        pctpubliccoverage
# 10  370.531211         avghouseholdsize
# 17  227.288884       pctemployed16_over
# 23  205.343876   pctpubliccoveragealone
# 24  185.076272                 pctwhite
# 20  147.202128  pctprivatecoveragealone
# 21  146.849604       pctempprivcoverage
# 2   122.998896            incidencerate
# 15  101.845191             pcths25_over
# 5    66.387444           povertypercent
# 7    59.741553                binnedinc
# 16   45.332908        pctbachdeg25_over
# 13   28.849820               pcths18_24
# 18   19.960282     pctunemployed16_over
# 29   15.162702                birthrate
# 1    14.214937         avgdeathsperyear
# ...

# %%
inp_2=inp_1.drop(['pctmarriedhouseholds'],1)      #check individual then add one by one into drop 
vif=pd.DataFrame()
vif['VIF']=[variance_inflation_factor(inp_2.values,i) for i in range(inp_2.shape[1])]
vif['feature']=inp_2.columns
vif.sort_values('VIF',ascending=False)
# Out:
#            VIF                  feature
# 9   730.779057          medianagefemale
# 8   635.124972            medianagemale
# 19  556.643644       pctprivatecoverage
# 3   434.580021                medincome
# 22  426.987442        pctpubliccoverage
# 10  272.643568         avghouseholdsize
# 11  239.703320           percentmarried
# 23  204.051006   pctpubliccoveragealone
# 17  183.237581       pctemployed16_over
# 24  181.408756                 pctwhite
# 20  147.198452  pctprivatecoveragealone
# 21  146.755369       pctempprivcoverage
# 2   121.061486            incidencerate
# 15  101.839782             pcths25_over
# 5    66.383973           povertypercent
# 7    59.741226                binnedinc
# 16   45.183545        pctbachdeg25_over
# 13   28.806428               pcths18_24
# 18   19.843737     pctunemployed16_over
# 28   15.034851                birthrate
# 1    14.193702         avgdeathsperyear
# 4    13.002578               popest2015
# ...

# %%
inp_3=inp_2.drop(['medianagefemale'],1)      #check individual then add one by one into drop 
vif=pd.DataFrame()
vif['VIF']=[variance_inflation_factor(inp_3.values,i) for i in range(inp_3.shape[1])]
vif['feature']=inp_3.columns
vif.sort_values('VIF',ascending=False)
# Out:
#            VIF                  feature
# 18  548.080422       pctprivatecoverage
# 3   431.542861                medincome
# 21  400.546533        pctpubliccoverage
# 9   268.577136         avghouseholdsize
# 8   257.587725            medianagemale
# 10  239.699856           percentmarried
# 22  201.523029   pctpubliccoveragealone
# 16  182.508176       pctemployed16_over
# 23  180.204962                 pctwhite
# 19  146.870728  pctprivatecoveragealone
# 20  146.071943       pctempprivcoverage
# 2   121.044075            incidencerate
# 14  101.530945             pcths25_over
# 5    66.302426           povertypercent
# 7    59.537110                binnedinc
# 15   44.964326        pctbachdeg25_over
# 12   28.688010               pcths18_24
# 17   19.770356     pctunemployed16_over
# 27   15.034816                birthrate
# 1    14.156535         avgdeathsperyear
# 4    12.977809               popest2015
# 11   11.546366             pctnohs18_24
# ...

# %%
inp_4=inp_3.drop(['pctprivatecoverage'],1)      #check individual then add one by one into drop 
vif=pd.DataFrame()
vif['VIF']=[variance_inflation_factor(inp_4.values,i) for i in range(inp_4.shape[1])]
vif['feature']=inp_4.columns
vif.sort_values('VIF',ascending=False)
# Out:
#            VIF                  feature
# 3   425.850293                medincome
# 20  318.524186        pctpubliccoverage
# 9   267.965462         avghouseholdsize
# 8   257.552000            medianagemale
# 10  235.384364           percentmarried
# 16  181.331725       pctemployed16_over
# 22  174.780729                 pctwhite
# 18  129.495805  pctprivatecoveragealone
# 21  128.332023   pctpubliccoveragealone
# 2   119.215598            incidencerate
# 19  115.450611       pctempprivcoverage
# 14   99.537248             pcths25_over
# 5    65.841007           povertypercent
# 7    59.537110                binnedinc
# 15   43.003420        pctbachdeg25_over
# 12   28.561418               pcths18_24
# 17   19.728721     pctunemployed16_over
# 26   14.891229                birthrate
# 1    14.129030         avgdeathsperyear
# 4    12.976057               popest2015
# 11   11.210300             pctnohs18_24
# 13    7.127713          pctbachdeg18_24
# ...

# %%
inp_5=inp_4.drop(['medincome'],1)      #check individual then add one by one into drop 
vif=pd.DataFrame()
vif['VIF']=[variance_inflation_factor(inp_5.values,i) for i in range(inp_5.shape[1])]
vif['feature']=inp_5.columns
vif.sort_values('VIF',ascending=False)
# Out:
#            VIF                  feature
# 19  318.155651        pctpubliccoverage
# 7   246.021411            medianagemale
# 8   236.473875         avghouseholdsize
# 9   231.389025           percentmarried
# 15  180.922793       pctemployed16_over
# 21  173.997082                 pctwhite
# 17  129.200115  pctprivatecoveragealone
# 20  128.143599   pctpubliccoveragealone
# 2   119.088958            incidencerate
# 18  108.131632       pctempprivcoverage
# 13   99.335403             pcths25_over
# 4    64.978434           povertypercent
# 14   41.682487        pctbachdeg25_over
# 11   28.483936               pcths18_24
# 6    25.319557                binnedinc
# 16   19.635166     pctunemployed16_over
# 25   14.875067                birthrate
# 1    14.129018         avgdeathsperyear
# 3    12.975134               popest2015
# 10   11.087387             pctnohs18_24
# 12    7.113163          pctbachdeg18_24
# 22    6.279242                 pctblack
# ...

# %%
inp_6=inp_5.drop(['pctpubliccoverage'],1)      #check individual then add one by one into drop 
vif=pd.DataFrame()
vif['VIF']=[variance_inflation_factor(inp_6.values,i) for i in range(inp_6.shape[1])]
vif['feature']=inp_6.columns
vif.sort_values('VIF',ascending=False)
# Out:
#            VIF                  feature
# 8   234.964194         avghouseholdsize
# 9   230.725797           percentmarried
# 15  173.119765       pctemployed16_over
# 20  170.899744                 pctwhite
# 7   156.840301            medianagemale
# 17  129.172554  pctprivatecoveragealone
# 2   115.970784            incidencerate
# 18  103.631855       pctempprivcoverage
# 13   98.356611             pcths25_over
# 4    64.482960           povertypercent
# 19   54.421668   pctpubliccoveragealone
# 14   41.500885        pctbachdeg25_over
# 11   28.334879               pcths18_24
# 6    25.300996                binnedinc
# 16   19.526956     pctunemployed16_over
# 24   14.793196                birthrate
# 1    14.128558         avgdeathsperyear
# 3    12.964295               popest2015
# 10   11.054169             pctnohs18_24
# 12    7.109541          pctbachdeg18_24
# 21    6.218615                 pctblack
# 26    4.604792                    South
# ...

# %%
inp_7=inp_6.drop(['avghouseholdsize'],1)      #check individual then add one by one into drop 
vif=pd.DataFrame()
vif['VIF']=[variance_inflation_factor(inp_7.values,i) for i in range(inp_7.shape[1])]
vif['feature']=inp_7.columns
vif.sort_values('VIF',ascending=False)
# Out:
#            VIF                  feature
# 8   214.929964           percentmarried
# 19  170.892083                 pctwhite
# 14  165.605217       pctemployed16_over
# 7   145.618277            medianagemale
# 16  128.268485  pctprivatecoveragealone
# 2   115.970744            incidencerate
# 17  101.678316       pctempprivcoverage
# 12   96.268624             pcths25_over
# 4    58.791465           povertypercent
# 18   53.124627   pctpubliccoveragealone
# 13   41.181616        pctbachdeg25_over
# 10   27.978610               pcths18_24
# 6    23.818681                binnedinc
# 15   17.810248     pctunemployed16_over
# 23   14.737903                birthrate
# 1    14.077319         avgdeathsperyear
# 3    12.891813               popest2015
# 9    10.592534             pctnohs18_24
# 11    7.103819          pctbachdeg18_24
# 20    6.215670                 pctblack
# 25    4.307680                    South
# 21    4.226071                 pctasian
# ...

# %%
inp_8=inp_7.drop(['percentmarried'],1)      #check individual then add one by one into drop 
vif=pd.DataFrame()
vif['VIF']=[variance_inflation_factor(inp_8.values,i) for i in range(inp_8.shape[1])]
vif['feature']=inp_8.columns
vif.sort_values('VIF',ascending=False)
# Out:
#            VIF                  feature
# 18  153.402458                 pctwhite
# 13  151.554336       pctemployed16_over
# 15  127.531035  pctprivatecoveragealone
# 7   123.798080            medianagemale
# 2   115.670362            incidencerate
# 16  101.204527       pctempprivcoverage
# 11   96.075941             pcths25_over
# 4    57.388844           povertypercent
# 17   53.098247   pctpubliccoveragealone
# 12   41.147721        pctbachdeg25_over
# 9    27.753230               pcths18_24
# 6    23.795851                binnedinc
# 14   17.802435     pctunemployed16_over
# 22   14.134716                birthrate
# 1    14.020348         avgdeathsperyear
# 3    12.872613               popest2015
# 8    10.266864             pctnohs18_24
# 10    7.099522          pctbachdeg18_24
# 19    6.205912                 pctblack
# 20    4.220421                 pctasian
# 24    4.136881                    South
# 0     3.573339              avganncount
# ...

# %%
inp_9=inp_8.drop(['pctwhite'],1)      #check individual then add one by one into drop 
vif=pd.DataFrame()
vif['VIF']=[variance_inflation_factor(inp_9.values,i) for i in range(inp_9.shape[1])]
vif['feature']=inp_9.columns
vif.sort_values('VIF',ascending=False)
# Out:
#            VIF                  feature
# 13  147.233863       pctemployed16_over
# 15  125.398658  pctprivatecoveragealone
# 2   114.102748            incidencerate
# 16   97.603489       pctempprivcoverage
# 7    97.251075            medianagemale
# 11   95.173177             pcths25_over
# 4    56.828565           povertypercent
# 17   53.037879   pctpubliccoveragealone
# 12   41.126576        pctbachdeg25_over
# 9    27.697207               pcths18_24
# 6    23.734511                binnedinc
# 14   17.795595     pctunemployed16_over
# 21   14.079947                birthrate
# 1    14.016258         avgdeathsperyear
# 3    12.864384               popest2015
# 8    10.261578             pctnohs18_24
# 10    7.094748          pctbachdeg18_24
# 19    4.106753                 pctasian
# 23    4.083432                    South
# 0     3.570994              avganncount
# 20    2.591580             pctotherrace
# 18    2.586972                 pctblack
# ...

# %%
inp_10=inp_9.drop(['pctemployed16_over'],1)      #check individual then add one by one into drop 
vif=pd.DataFrame()
vif['VIF']=[variance_inflation_factor(inp_10.values,i) for i in range(inp_10.shape[1])]
vif['feature']=inp_10.columns
vif.sort_values('VIF',ascending=False)
# Out:
#            VIF                  feature
# 14  121.609834  pctprivatecoveragealone
# 2   110.518238            incidencerate
# 7    97.063026            medianagemale
# 15   93.229097       pctempprivcoverage
# 11   92.780211             pcths25_over
# 4    56.760715           povertypercent
# 16   51.530164   pctpubliccoveragealone
# 12   36.607787        pctbachdeg25_over
# 9    27.675014               pcths18_24
# 6    23.123257                binnedinc
# 13   16.605498     pctunemployed16_over
# 1    13.916212         avgdeathsperyear
# 20   13.409490                birthrate
# 3    12.856126               popest2015
# 8    10.232568             pctnohs18_24
# 10    7.049062          pctbachdeg18_24
# 18    4.106751                 pctasian
# 22    4.032080                    South
# 0     3.568124              avganncount
# 17    2.586818                 pctblack
# 19    2.460287             pctotherrace
# 23    2.090127                     West
# ...

# %%
inp_11=inp_10.drop(['pctprivatecoveragealone'],1)      #check individual then add one by one into drop 
vif=pd.DataFrame()
vif['VIF']=[variance_inflation_factor(inp_11.values,i) for i in range(inp_11.shape[1])]
vif['feature']=inp_11.columns
vif.sort_values('VIF',ascending=False)
# Out:
#            VIF                 feature
# 2   108.537409           incidencerate
# 7    95.104343           medianagemale
# 11   90.928237            pcths25_over
# 14   67.160909      pctempprivcoverage
# 4    55.087218          povertypercent
# 15   49.490728  pctpubliccoveragealone
# 12   35.088733       pctbachdeg25_over
# 9    27.667154              pcths18_24
# 6    22.517205               binnedinc
# 13   16.605240    pctunemployed16_over
# 1    13.828891        avgdeathsperyear
# 19   13.266639               birthrate
# 3    12.827649              popest2015
# 8    10.211271            pctnohs18_24
# 10    7.043264         pctbachdeg18_24
# 17    4.105205                pctasian
# 21    4.024155                   South
# 0     3.568019             avganncount
# 16    2.586676                pctblack
# 18    2.447511            pctotherrace
# 22    2.089410                    West
# 5     1.604557             studypercap
# 20    1.462799              North-East

# %%
inp_12=inp_11.drop(['incidencerate'],1)      #check individual then add one by one into drop 
vif=pd.DataFrame()
vif['VIF']=[variance_inflation_factor(inp_12.values,i) for i in range(inp_12.shape[1])]
vif['feature']=inp_12.columns
vif.sort_values('VIF',ascending=False)
# Out:
#           VIF                 feature
# 6   90.981764           medianagemale
# 10  88.426448            pcths25_over
# 13  61.973769      pctempprivcoverage
# 3   53.396206          povertypercent
# 14  48.141196  pctpubliccoveragealone
# 11  34.612820       pctbachdeg25_over
# 8   27.622139              pcths18_24
# 5   22.098604               binnedinc
# 12  16.381360    pctunemployed16_over
# 1   13.828888        avgdeathsperyear
# 18  13.192661               birthrate
# 2   12.803250              popest2015
# 7   10.206196            pctnohs18_24
# 9    7.042173         pctbachdeg18_24
# 16   4.096492                pctasian
# 20   3.991820                   South
# 0    3.518993             avganncount
# 15   2.586668                pctblack
# 17   2.413213            pctotherrace
# 21   2.082638                    West
# 4    1.593103             studypercap
# 19   1.449925              North-East

# %%
inp_13=inp_12.drop(['medianagemale'],1)      #check individual then add one by one into drop 
vif=pd.DataFrame()
vif['VIF']=[variance_inflation_factor(inp_13.values,i) for i in range(inp_13.shape[1])]
vif['feature']=inp_13.columns
vif.sort_values('VIF',ascending=False)
# Out:
#           VIF                 feature
# 9   67.512559            pcths25_over
# 12  61.807657      pctempprivcoverage
# 3   52.584224          povertypercent
# 13  46.208266  pctpubliccoveragealone
# 7   26.531507              pcths18_24
# 10  24.515920       pctbachdeg25_over
# 5   22.064157               binnedinc
# 11  16.180896    pctunemployed16_over
# 1   13.796766        avgdeathsperyear
# 17  13.183308               birthrate
# 2   12.570150              popest2015
# 6    9.719575            pctnohs18_24
# 8    6.876414         pctbachdeg18_24
# 15   4.015850                pctasian
# 19   3.962088                   South
# 0    3.477943             avganncount
# 14   2.532741                pctblack
# 16   2.395038            pctotherrace
# 20   2.062132                    West
# 4    1.590633             studypercap
# 18   1.449901              North-East

# %%
inp_14=inp_13.drop(['pcths25_over'],1)      #check individual then add one by one into drop 
vif=pd.DataFrame()
vif['VIF']=[variance_inflation_factor(inp_14.values,i) for i in range(inp_14.shape[1])]
vif['feature']=inp_14.columns
vif.sort_values('VIF',ascending=False)
# Out:
#           VIF                 feature
# 3   51.354161          povertypercent
# 11  43.698361      pctempprivcoverage
# 12  43.354547  pctpubliccoveragealone
# 9   22.201693       pctbachdeg25_over
# 5   22.062077               binnedinc
# 7   20.703331              pcths18_24
# 10  16.162484    pctunemployed16_over
# 1   13.761250        avgdeathsperyear
# 16  13.035532               birthrate
# 2   12.450179              popest2015
# 6    9.171949            pctnohs18_24
# 8    6.737908         pctbachdeg18_24
# 18   3.914535                   South
# 14   3.902561                pctasian
# 0    3.471568             avganncount
# 13   2.510370                pctblack
# 15   2.257638            pctotherrace
# 19   2.002945                    West
# 4    1.583253             studypercap
# 17   1.444281              North-East

# %%
inp_15=inp_14.drop(['povertypercent'],1)      #check individual then add one by one into drop 
vif=pd.DataFrame()
vif['VIF']=[variance_inflation_factor(inp_15.values,i) for i in range(inp_15.shape[1])]
vif['feature']=inp_15.columns
vif.sort_values('VIF',ascending=False)
# Out:
#           VIF                 feature
# 10  37.384168      pctempprivcoverage
# 11  30.657856  pctpubliccoveragealone
# 8   20.821890       pctbachdeg25_over
# 6   20.701788              pcths18_24
# 9   15.392323    pctunemployed16_over
# 4   13.839160               binnedinc
# 1   13.653500        avgdeathsperyear
# 15  12.619910               birthrate
# 2   12.432085              popest2015
# 5    9.033899            pctnohs18_24
# 7    6.737664         pctbachdeg18_24
# 13   3.879313                pctasian
# 17   3.844401                   South
# 0    3.466105             avganncount
# 12   2.382413                pctblack
# 14   2.220952            pctotherrace
# 18   1.994573                    West
# 3    1.582327             studypercap
# 16   1.442263              North-East

# %%
inp_16=inp_15.drop(['pctempprivcoverage'],1)      #check individual then add one by one into drop 
vif=pd.DataFrame()
vif['VIF']=[variance_inflation_factor(inp_16.values,i) for i in range(inp_16.shape[1])]
vif['feature']=inp_16.columns
vif.sort_values('VIF',ascending=False)
# Out:
#           VIF                 feature
# 10  30.200003  pctpubliccoveragealone
# 8   19.452438       pctbachdeg25_over
# 6   19.105588              pcths18_24
# 9   15.119078    pctunemployed16_over
# 1   13.579783        avgdeathsperyear
# 14  12.424974               birthrate
# 2   12.423144              popest2015
# 4   10.220103               binnedinc
# 5    8.995743            pctnohs18_24
# 7    6.401825         pctbachdeg18_24
# 12   3.869334                pctasian
# 16   3.838489                   South
# 0    3.466036             avganncount
# 11   2.382086                pctblack
# 13   2.198778            pctotherrace
# 17   1.893139                    West
# 3    1.566113             studypercap
# 15   1.442139              North-East

# %%
inp_17=inp_16.drop(['pctpubliccoveragealone'],1)      #check individual then add one by one into drop 
vif=pd.DataFrame()
vif['VIF']=[variance_inflation_factor(inp_17.values,i) for i in range(inp_17.shape[1])]
vif['feature']=inp_17.columns
vif.sort_values('VIF',ascending=False)
# Out:
#           VIF               feature
# 8   19.115507     pctbachdeg25_over
# 6   15.885597            pcths18_24
# 1   13.539222      avgdeathsperyear
# 2   12.398561            popest2015
# 13  11.684294             birthrate
# 9   10.693209  pctunemployed16_over
# 4    8.198292             binnedinc
# 5    8.161904          pctnohs18_24
# 7    6.278785       pctbachdeg18_24
# 11   3.836265              pctasian
# 15   3.818511                 South
# 0    3.460638           avganncount
# 10   2.379634              pctblack
# 12   2.174912          pctotherrace
# 16   1.891153                  West
# 3    1.563181           studypercap
# 14   1.423057            North-East

# %%
inp_18=inp_17.drop(['pctbachdeg25_over'],1)      #check individual then add one by one into drop 
vif=pd.DataFrame()
vif['VIF']=[variance_inflation_factor(inp_18.values,i) for i in range(inp_18.shape[1])]
vif['feature']=inp_18.columns
vif.sort_values('VIF',ascending=False)
# Out:
#           VIF               feature
# 6   15.774687            pcths18_24
# 1   13.518398      avgdeathsperyear
# 2   12.373257            popest2015
# 12  11.298930             birthrate
# 8   10.675084  pctunemployed16_over
# 5    8.117521          pctnohs18_24
# 4    6.253901             binnedinc
# 7    4.954816       pctbachdeg18_24
# 14   3.737644                 South
# 10   3.656894              pctasian
# 0    3.441707           avganncount
# 9    2.378455              pctblack
# 11   2.142471          pctotherrace
# 15   1.773573                  West
# 3    1.542808           studypercap
# 13   1.422069            North-East

# %%
inp_19=inp_18.drop(['pcths18_24'],1)      #check individual then add one by one into drop 
vif=pd.DataFrame()
vif['VIF']=[variance_inflation_factor(inp_19.values,i) for i in range(inp_19.shape[1])]
vif['feature']=inp_19.columns
vif.sort_values('VIF',ascending=False)
# Out:
#           VIF               feature
# 1   13.501246      avgdeathsperyear
# 2   12.279776            popest2015
# 11   9.886948             birthrate
# 7    8.728805  pctunemployed16_over
# 5    7.733674          pctnohs18_24
# 4    5.528353             binnedinc
# 6    4.951231       pctbachdeg18_24
# 9    3.609981              pctasian
# 0    3.441500           avganncount
# 13   3.433147                 South
# 8    2.320810              pctblack
# 10   2.124573          pctotherrace
# 14   1.761624                  West
# 3    1.542526           studypercap
# 12   1.405859            North-East

# %%
inp_20=inp_19.drop(['avgdeathsperyear'],1)      #check individual then add one by one into drop 
vif=pd.DataFrame()
vif['VIF']=[variance_inflation_factor(inp_20.values,i) for i in range(inp_20.shape[1])]
vif['feature']=inp_20.columns
vif.sort_values('VIF',ascending=False)
# Out:
#          VIF               feature
# 10  9.835237             birthrate
# 6   8.578720  pctunemployed16_over
# 4   7.731574          pctnohs18_24
# 3   5.519634             binnedinc
# 5   4.951231       pctbachdeg18_24
# 1   3.836527            popest2015
# 8   3.609233              pctasian
# 12  3.425989                 South
# 0   3.159133           avganncount
# 7   2.320133              pctblack
# 9   2.118921          pctotherrace
# 13  1.761620                  West
# 2   1.525798           studypercap
# 11  1.366693            North-East

# %%
inp_21=inp_20.drop(['birthrate'],1)      #check individual then add one by one into drop 
vif=pd.DataFrame()
vif['VIF']=[variance_inflation_factor(inp_21.values,i) for i in range(inp_21.shape[1])]
vif['feature']=inp_21.columns
vif.sort_values('VIF',ascending=False)
# Out:
#          VIF               feature
# 6   7.597100  pctunemployed16_over
# 4   6.457446          pctnohs18_24
# 3   4.875943             binnedinc
# 5   4.811384       pctbachdeg18_24
# 1   3.750633            popest2015
# 8   3.606724              pctasian
# 11  3.419758                 South
# 0   3.131267           avganncount
# 7   2.312791              pctblack
# 9   2.111231          pctotherrace
# 12  1.761573                  West
# 2   1.523722           studypercap
# 10  1.355862            North-East

# %%
inp_22=inp_21.drop(['pctunemployed16_over'],1)      #check individual then add one by one into drop 
vif=pd.DataFrame()
vif['VIF']=[variance_inflation_factor(inp_22.values,i) for i in range(inp_22.shape[1])]
vif['feature']=inp_22.columns
vif.sort_values('VIF',ascending=False)
# Out:
#          VIF          feature
# 3   4.800755        binnedinc
# 5   4.725182  pctbachdeg18_24
# 4   4.123635     pctnohs18_24
# 1   3.747043       popest2015
# 7   3.572099         pctasian
# 0   3.120236      avganncount
# 10  3.030357            South
# 6   2.209597         pctblack
# 8   2.095174     pctotherrace
# 11  1.610006             West
# 2   1.509711      studypercap
# 9   1.303077       North-East

# %%
inp_23=inp_22.drop(['binnedinc'],1)      #check individual then add one by one into drop 
vif=pd.DataFrame()
vif['VIF']=[variance_inflation_factor(inp_23.values,i) for i in range(inp_23.shape[1])]
vif['feature']=inp_23.columns
vif.sort_values('VIF',ascending=False)
# Out:
#         VIF          feature
# 1  3.645086       popest2015
# 6  3.392701         pctasian
# 4  3.329821  pctbachdeg18_24
# 0  2.931859      avganncount
# 3  2.856328     pctnohs18_24
# 7  1.919223     pctotherrace
# 5  1.523650         pctblack
# 2  1.486209      studypercap

# %%
inp_c = sm.add_constant(inp_22)

# %%
mod = sm.OLS(out,inp_c)
ols_mod = mod.fit()
ols_mod.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:       target_deathrate   R-squared:                       0.318
# Model:                            OLS   Adj. R-squared:                  0.315
# Method:                 Least Squares   F-statistic:                     118.0
# Date:                Sat, 12 Sep 2020   Prob (F-statistic):          1.13e-241
# Time:                        11:09:09   Log-Likelihood:                -13625.
# No. Observations:                3047   AIC:                         2.728e+04
# Df Residuals:                    3034   BIC:                         2.735e+04
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
out.skew()
# Out:
# 0.03441522893965067

# %%
Q1 = d.quantile(0.25)
Q3 = d.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# avganncount                  442.000000
# avgdeathsperyear             121.000000
# target_deathrate              34.000000
# incidencerate                 60.550000
# medincome                  13609.500000
# popest2015                 56987.000000
# povertypercent                 8.250000
# studypercap                   83.650776
# binnedinc                      5.000000
# medianage                      6.300000
# medianagemale                  6.150000
# medianagefemale                6.200000
# avghouseholdsize               0.260000
# percentmarried                 8.650000
# pctnohs18_24                   9.900000
# pcths18_24                    11.500000
# pctbachdeg18_24                5.100000
# pcths25_over                   9.250000
# pctbachdeg25_over              6.700000
# pctemployed16_over            11.100000
# pctunemployed16_over           4.200000
# pctprivatecoverage            14.900000
# pctprivatecoveragealone       10.700000
# ...

# %%
out=d_out["target_deathrate"]
inp=d_out.drop(columns=["target_deathrate"])

# %%
print(d < (Q1 - 1.5 * IQR)) |(d > (Q3 + 1.5 * IQR))
# Out:
#       avganncount  avgdeathsperyear  target_deathrate  incidencerate  \
# 0           False             False             False          False
# 1           False             False             False          False
# 2           False             False             False          False
# 3           False             False             False          False
# 4           False             False             False          False
# ...           ...               ...               ...            ...
# 3042        False             False             False          False
# 3043        False             False             False          False
# 3044        False             False             False          False
# 3045        False             False             False          False
# 3046        False             False             False          False
#
#       medincome  popest2015  povertypercent  studypercap  binnedinc  \
# 0         False       False           False        False      False
# ...

# %%
d_out = d[~((d < (Q1 - 1.5 * IQR)) |(d > (Q3 + 1.5 * IQR))).any(axis=1)]
d_out.shape
# Out:
# (1230, 32)

# %%
d_out
# Out:
#       avganncount  avgdeathsperyear  target_deathrate  incidencerate  \
# 1           173.0                70             161.3          411.6
# 2           102.0                50             174.7          349.7
# 4            57.0                26             144.4          350.1
# 5           428.0               152             176.0          505.4
# 7           146.0                71             183.6          404.0
# ...           ...               ...               ...            ...
# 3005         46.0                19             181.3          475.5
# 3007         50.0                21             181.9          463.5
# 3014        113.0                40             138.4          431.4
# 3016         49.0                16             136.5          470.0
# 3017         87.0                34             159.3          453.2
#
#       medincome  popest2015  povertypercent  studypercap  binnedinc  \
# 1         48127       43269            18.6    23.111234          6
# ...
